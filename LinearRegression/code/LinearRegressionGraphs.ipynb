# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
m = 1.3
b = 1
Xs = np.arange(0, 10, 0.1)
Ys = [(m * x) + b + np.random.normal() for x in Xs]

# %%
plt.plot(Xs,Ys, '.')
plt.savefig('../fig/simple_lin_reg_GEN.jpg')

# %%
plt.plot(Xs,Ys, '.')
plt.plot(Xs, m*Xs + b, '-')
plt.savefig('../fig/simple_lin_reg_w_line_GEN.jpg')

# %%
Xs = np.arange(-1, 5, 0.1)
plt.plot(Xs, -(Xs-2)**2 + 2, '-')
plt.plot([2], [2], 'x', color='red', markersize=10)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.axvline(2, color='gray', linestyle='dashed')
plt.savefig('../fig/deriv_at_2_GEN.jpg')

# %%
Xs = np.arange(0, 10, 0.1)
plt.axis([0.0,10.0,000000.0,40.0])
plt.plot(Xs, (Xs)**2, '-')
plt.savefig('../fig/lin_reg_no_basis_fn_GEN.jpg')

# %%
Xs = np.arange(0, 10, 0.1)
plt.axis([0.0,10.0,000000.0,40.0])
plt.plot(Xs, (Xs)**2, '-')
moreXs = np.arange(0, 100, 0.1)
plt.plot(0.18*moreXs, moreXs, linestyle='dashed')
plt.savefig('../fig/lin_reg_no_basis_fn_fitted_GEN.jpg')

# %%
Xs = np.arange(0, 10, 0.1)
plt.axis([0.0,10.0,000000.0,40.0])
plt.plot(Xs, (Xs)**2, '-', label=r'$X$')
plt.plot(Xs**2, (Xs)**2, color='red', label=r'$\sqrt{X}$')
plt.legend()
plt.savefig('../fig/lin_reg_w_basis_fn_GEN.jpg')

# %%
m = 1.3
b = 1
Xs = np.arange(0, 20, 1)
Ys = [(m * x) + b + (2*np.random.normal()) for x in Xs]
plt.plot(Xs,Ys, '.')
plt.savefig('../fig/data_set_scattered_GEN.jpg')

# %%
def find_weights(X,Y):
    w = np.linalg.solve(np.dot(X.T, X) , np.dot(X.T, Y))
    return w

def make_basis(Xs, num_fns):
    X = [np.ones(Xs.shape).T]
    for i in range(1, num_fns):
        X.append(Xs**i)
    return np.array(X).T

# %%
plt.plot(Xs,Ys, '.')
transformed_Xs = make_basis(Xs, 2)
fit_ws = find_weights(transformed_Xs, Ys)
new_Ys = np.dot(transformed_Xs, fit_ws)
plt.plot(Xs, new_Ys)
single_trans = make_basis(np.array([10]), 2)
print('single pred', np.dot(single_trans, fit_ws))
# plt.savefig('../fig/data_set_natural_fit_GEN.jpg')
# Out:
# single pred [14.07560644]

# %%
plt.plot(Xs,Ys, '.')
transformed_Xs = make_basis(Xs, 30)
fit_ws = find_weights(transformed_Xs, Ys)
new_Ys = np.dot(transformed_Xs, fit_ws)
plt.plot(Xs, new_Ys)
single_trans = make_basis(np.array([10]), 30)
print('single pred', np.dot(single_trans, fit_ws))
#plt.savefig('../fig/data_set_unnatural_fit_GEN.jpg')
# Out:
# single pred [9.54610957]

# %%
plt.plot(Xs,Ys, '.')
transformed_Xs = make_basis(Xs, 1)
fit_ws = find_weights(transformed_Xs, Ys)
new_Ys = np.dot(transformed_Xs, fit_ws)
plt.plot(Xs, new_Ys, label=r'$\lambda$ = 10000')

transformed_Xs = make_basis(Xs, 5)
fit_ws = find_weights(transformed_Xs, Ys)
new_Ys = np.dot(transformed_Xs, fit_ws)
plt.plot(Xs, new_Ys, label=r'$\lambda$ = 1')

transformed_Xs = make_basis(Xs, 30)
fit_ws = find_weights(transformed_Xs, Ys)
new_Ys = np.dot(transformed_Xs, fit_ws)
plt.plot(Xs, new_Ys, label=r'$\lambda$ = 0.00001')

plt.legend()
plt.savefig('../fig/diffregvalues_GEN.jpg')

# %%
Xs = np.arange(0, 10, 0.1)
plt.plot(Xs, 0.0002 * np.exp(Xs), label='bias')
plt.plot(Xs, 1 / np.sqrt(Xs), label='variance')
#plt.plot(Xs, 0.5 * np.sqrt(Xs), label='variance')
plt.ylabel('Error')
plt.xlabel(r'$\lambda$')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.legend()
plt.savefig('../fig/biasvariance_GEN.jpg')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# ridge
circle1 = plt.Circle((0,0), radius=5, fill=None, color='b', label='Ridge')
ax=plt.gca()
ax.add_patch(circle1)
plt.axis('scaled')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# lasso
Xs = np.arange(-5,5.1,0.1)
plt.plot(Xs, np.abs(Xs) - 5, color='r', label='Lasso')
plt.plot(Xs, -np.abs(Xs) + 5, color='r')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.legend()
plt.savefig('../fig/ridgeandlassoreg_GEN.jpg')

# %%
# now longer using
Xs = np.arange(-5,5.1,0.1)
plt.plot(Xs, np.abs(Xs) - 5, color='b')
plt.plot(Xs, -np.abs(Xs) + 5, color='b')
plt.axis('scaled')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    right=False,         # ticks along the top edge are off
    labelleft=False)
plt.savefig('../fig/lassoreg_GEN.jpg')
